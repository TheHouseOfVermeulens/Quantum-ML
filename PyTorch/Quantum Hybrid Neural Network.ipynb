# %% [markdown]
# It is possible to train a hybrid network with PyTorch! We can specify any PyTorch optimiser, learning rate and cost/loss function in order to train over multiple epochs. In this instance, we use the Adam optimiser, a learning rate of 0.001 and the negative log-likelihood loss function.

# %% [markdown]
# As mentioned in the Qiskit textbook (& code source) our quantum hybrid NN does not outperform a classical version and if we hope to achieve a quantum advantage using hybrid neural networks, we'll need to start by extending this code to include a more sophisticated quantum layer. But for my purpose today it works perfectly fine.

# %%
#Step1: Install necessary libraries in python
# !pip install qiskit
# !pip install pytorch

# %%
#Step2: Import necessary libraries in Colab or python framework
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Function
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import qiskit
from qiskit import transpile, assemble
from qiskit.visualization import *

# %%
#Step3: Create a “Quantum Class” with Qiskit

class QuantumCircuit:
    """This class provides a simple interface for interactionwith the quantum circuit"""

    def __init__(self, n_qubits, backend, shots):
        # --- Circuit definition ---
        self._circuit = qiskit.QuantumCircuit(n_qubits)
        all_qubits = [i for i in range(n_qubits)]
        self.theta = qiskit.circuit.Parameter('theta')
        self._circuit.h(all_qubits)
        self._circuit.barrier()
        self._circuit.ry(self.theta, all_qubits)
        self._circuit.measure_all()
        # ---------------------------
        self.backend = backend
        self.shots = shots

    def run(self, thetas):
        t_qc = transpile(self._circuit,self.backend)
        qobj = assemble(t_qc,shots=self.shots,
        parameter_binds = [{self.theta: theta} for theta in thetas])
        job = self.backend.run(qobj)
        result = job.result().get_counts()
        counts = np.array(list(result.values()))
        states = np.array(list(result.keys())).astype(float)
        # Compute probabilities for each state
        probabilities = counts / self.shots
        # Get state expectation
        expectation = np.sum(states * probabilities)
        return np.array([expectation])

# %%
#Let’s test the implementation

simulator = qiskit.Aer.get_backend('aer_simulator')
circuit = QuantumCircuit(1, simulator, 100)
print('Expected value for rotation pi {}'.format(circuit.run([np.pi])[0]))
circuit._circuit.draw()
# Out:
# Expected value for rotation pi 0.5
#         ┌───┐ ░ ┌───────────┐ ░ ┌─┐
#      q: ┤ H ├─░─┤ Ry(theta) ├─░─┤M├
#         └───┘ ░ └───────────┘ ░ └╥┘
# meas: 1/═════════════════════════╩═
#                                  0

# %%
#Step4: Create a “Quantum-Classical Class” with PyTorch

class HybridFunction(Function):
    """ Hybrid quantum - classical function definition """
    @staticmethod
    def forward(ctx, input, quantum_circuit, shift):
        """ Forward pass computation """
        ctx.shift = shift
        ctx.quantum_circuit = quantum_circuit
        expectation_z = ctx.quantum_circuit.run(input[0].tolist())
        result = torch.tensor([expectation_z])
        ctx.save_for_backward(input, result)
        return result
 
    @staticmethod
    def backward(ctx, grad_output):
        """ Backward pass computation """
        input, expectation_z = ctx.saved_tensors
        input_list = np.array(input.tolist())
        shift_right = input_list + np.ones(input_list.shape) * ctx.shift
        shift_left = input_list - np.ones(input_list.shape) * ctx.shift
        gradients = []
        for i in range(len(input_list)):
            expectation_right = ctx.quantum_circuit.run(shift_right[i])
            expectation_left  = ctx.quantum_circuit.run(shift_left[i])
            
            gradient = torch.tensor([expectation_right]) - torch.tensor([expectation_left])
            gradients.append(gradient)
        gradients = np.array([gradients]).T
        return torch.tensor([gradients]).float() * grad_output.float(), None, None

class Hybrid(nn.Module):
    """ Hybrid quantum - classical layer definition """
    def __init__(self, backend, shots, shift):
        super(Hybrid, self).__init__()
        self.quantum_circuit = QuantumCircuit(1, backend, shots)
        self.shift = shift

    def forward(self, input):
        return HybridFunction.apply(input, self.quantum_circuit, self.shift)

# %%
#Step5: Data Loading and Preprocessing
#Our idea is to create a simple hybrid neural network that classifies images of the digits 0 and 1 from the MNIST dataset. The foremost thing to do is to load MNIST and filter all the pictures with 0’s and 1’s. We’ll use these as inputs in our neural network.
#Training Data codes:
# Concentrating on the first 100 samples
n_samples = 100
X_train = datasets.MNIST(root='./data', train=True, download=True,transform=transforms.Compose([transforms.ToTensor()]))
# Leaving only labels 0 and 1
idx = np.append(np.where(X_train.targets == 0)[0][:n_samples],np.where(X_train.targets == 1)[0][:n_samples])
X_train.data = X_train.data[idx]
X_train.targets = X_train.targets[idx]
train_loader = torch.utils.data.DataLoader(X_train, batch_size=1, shuffle=True)

# %%
n_samples_show = 6
data_iter = iter(train_loader)
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 3))
while n_samples_show > 0:
    images, targets = data_iter.__next__()
    axes[n_samples_show - 1].imshow(images[0].numpy().squeeze(), cmap='gray')
    axes[n_samples_show - 1].set_xticks([])
    axes[n_samples_show - 1].set_yticks([])
    axes[n_samples_show - 1].set_title("Labeled: {}".format(targets.item()))
    n_samples_show -= 1

# %%
#Testing Data codes:
n_samples = 50
X_test = datasets.MNIST(root='./data', train=False, download=True,transform=transforms.Compose([transforms.ToTensor()]))
idx = np.append(np.where(X_test.targets == 0)[0][:n_samples],np.where(X_test.targets == 1)[0][:n_samples])
X_test.data = X_test.data[idx]
X_test.targets = X_test.targets[idx]
test_loader = torch.utils.data.DataLoader(X_test, batch_size=1, shuffle=True)

# %%
#Step6: Creating the Hybrid Neural Network
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, kernel_size=5)
        self.conv2 = nn.Conv2d(6, 16, kernel_size=5)
        self.dropout = nn.Dropout2d()
        self.fc1 = nn.Linear(256, 64)
        self.fc2 = nn.Linear(64, 1)
        self.hybrid = Hybrid(qiskit.Aer.get_backend('aer_simulator'), 100, np.pi / 2)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = self.dropout(x)
        x = x.view(1, -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x = self.hybrid(x)
        return torch.cat((x, 1 - x), -1)

# %%
#Step7: Training the Network
model = Net()
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_func = nn.NLLLoss()
epochs = 20
loss_list = []
model.train()
for epoch in range(epochs):
   total_loss = []
for batch_idx, (data, target) in enumerate(train_loader):
   optimizer.zero_grad()
   # Forward pass
   output = model(data)
   # Calculating loss
   loss = loss_func(output, target)
   # Backward pass
   loss.backward()
   # Optimize the weights
   optimizer.step()
   total_loss.append(loss.item())
   loss_list.append(sum(total_loss)/len(total_loss))
   print('Training [{:.0f}%]\tLoss: {:.4f}'.format(100. * (epoch + 1) / epochs, loss_list[-1]))

#Plot the training graph
plt.plot(loss_list)
plt.title('Hybrid NN Training Convergence')
plt.xlabel('Training Iterations')
plt.ylabel('Neg Log Likelihood Loss')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
# Training [100%]	Loss: -0.5600
# Training [100%]	Loss: -0.5200
# Training [100%]	Loss: -0.5400
# Training [100%]	Loss: -0.5300
# Training [100%]	Loss: -0.5360
# Training [100%]	Loss: -0.5333
# Training [100%]	Loss: -0.5186
# Training [100%]	Loss: -0.5200
# Training [100%]	Loss: -0.5122
# Training [100%]	Loss: -0.5180
# Training [100%]	Loss: -0.5182
# Training [100%]	Loss: -0.5208
# Training [100%]	Loss: -0.5138
# Training [100%]	Loss: -0.5107
# Training [100%]	Loss: -0.5140
# Training [100%]	Loss: -0.5075
# Training [100%]	Loss: -0.5112
# Training [100%]	Loss: -0.5094
# Training [100%]	Loss: -0.5058
# Training [100%]	Loss: -0.5080
# Training [100%]	Loss: -0.5062
# Training [100%]	Loss: -0.5068
# Training [100%]	Loss: -0.5078
# Training [100%]	Loss: -0.5079
# Training [100%]	Loss: -0.5088
# Training [100%]	Loss: -0.5081
# Training [100%]	Loss: -0.5089
# Training [100%]	Loss: -0.5100
# Training [100%]	Loss: -0.5100
# Training [100%]	Loss: -0.5130
# Training [100%]	Loss: -0.5139
# Training [100%]	Loss: -0.5134
# Training [100%]	Loss: -0.5127
# Training [100%]	Loss: -0.5103
# Training [100%]	Loss: -0.5077
# Training [100%]	Loss: -0.5089
# Training [100%]	Loss: -0.5089
# Training [100%]	Loss: -0.5084
# Training [100%]	Loss: -0.5092
# Training [100%]	Loss: -0.5115
# Training [100%]	Loss: -0.5105
# Training [100%]	Loss: -0.5100
# Training [100%]	Loss: -0.5098
# Training [100%]	Loss: -0.5120
# Training [100%]	Loss: -0.5140
# Training [100%]	Loss: -0.5139
# Training [100%]	Loss: -0.5179
# Training [100%]	Loss: -0.5217
# Training [100%]	Loss: -0.5237
# Training [100%]	Loss: -0.5278
# Training [100%]	Loss: -0.5337
# Training [100%]	Loss: -0.5331
# Training [100%]	Loss: -0.5302
# Training [100%]	Loss: -0.5359
# Training [100%]	Loss: -0.5329
# Training [100%]	Loss: -0.5405
# Training [100%]	Loss: -0.5486
# Training [100%]	Loss: -0.5564
# Training [100%]	Loss: -0.5544
# Training [100%]	Loss: -0.5535
# Training [100%]	Loss: -0.5557
# Training [100%]	Loss: -0.5598
# Training [100%]	Loss: -0.5644
# Training [100%]	Loss: -0.5695
# Training [100%]	Loss: -0.5755
# Training [100%]	Loss: -0.5815
# Training [100%]	Loss: -0.5851
# Training [100%]	Loss: -0.5904
# Training [100%]	Loss: -0.5936
# Training [100%]	Loss: -0.5983
# Training [100%]	Loss: -0.5959
# Training [100%]	Loss: -0.5935
# Training [100%]	Loss: -0.5951
# Training [100%]	Loss: -0.5985
# Training [100%]	Loss: -0.6025
# Training [100%]	Loss: -0.6076
# Training [100%]	Loss: -0.6127
# Training [100%]	Loss: -0.6141
# Training [100%]	Loss: -0.6189
# Training [100%]	Loss: -0.6234
# Training [100%]	Loss: -0.6225
# Training [100%]	Loss: -0.6215
# Training [100%]	Loss: -0.6255
# Training [100%]	Loss: -0.6281
# Training [100%]	Loss: -0.6325
# Training [100%]	Loss: -0.6362
# Training [100%]	Loss: -0.6399
# Training [100%]	Loss: -0.6434
# Training [100%]	Loss: -0.6465
# Training [100%]	Loss: -0.6500
# Training [100%]	Loss: -0.6525
# Training [100%]	Loss: -0.6538
# Training [100%]	Loss: -0.6556
# Training [100%]	Loss: -0.6579
# Training [100%]	Loss: -0.6613
# Training [100%]	Loss: -0.6648
# Training [100%]	Loss: -0.6672
# Training [100%]	Loss: -0.6706
# Training [100%]	Loss: -0.6717
# Training [100%]	Loss: -0.6750
# Training [100%]	Loss: -0.6765
# Training [100%]	Loss: -0.6781
# Training [100%]	Loss: -0.6779
# Training [100%]	Loss: -0.6796
# Training [100%]	Loss: -0.6821
# Training [100%]	Loss: -0.6840
# Training [100%]	Loss: -0.6853
# Training [100%]	Loss: -0.6880
# Training [100%]	Loss: -0.6889
# Training [100%]	Loss: -0.6915
# Training [100%]	Loss: -0.6938
# Training [100%]	Loss: -0.6960
# Training [100%]	Loss: -0.6933
# Training [100%]	Loss: -0.6959
# Training [100%]	Loss: -0.6985
# Training [100%]	Loss: -0.7009
# Training [100%]	Loss: -0.7035
# Training [100%]	Loss: -0.7049
# Training [100%]	Loss: -0.7070
# Training [100%]	Loss: -0.7072
# Training [100%]	Loss: -0.7083
# Training [100%]	Loss: -0.7106
# Training [100%]	Loss: -0.7119
# Training [100%]	Loss: -0.7141
# Training [100%]	Loss: -0.7162
# Training [100%]	Loss: -0.7176
# Training [100%]	Loss: -0.7198
# Training [100%]	Loss: -0.7205
# Training [100%]	Loss: -0.7226
# Training [100%]	Loss: -0.7247
# Training [100%]	Loss: -0.7266
# Training [100%]	Loss: -0.7280
# Training [100%]	Loss: -0.7299
# Training [100%]	Loss: -0.7319
# Training [100%]	Loss: -0.7337
# Training [100%]	Loss: -0.7357
# Training [100%]	Loss: -0.7375
# Training [100%]	Loss: -0.7393
# Training [100%]	Loss: -0.7406
# Training [100%]	Loss: -0.7418
# Training [100%]	Loss: -0.7433
# Training [100%]	Loss: -0.7448
# Training [100%]	Loss: -0.7466
# Training [100%]	Loss: -0.7477
# Training [100%]	Loss: -0.7492
# Training [100%]	Loss: -0.7505
# Training [100%]	Loss: -0.7518
# Training [100%]	Loss: -0.7531
# Training [100%]	Loss: -0.7526
# Training [100%]	Loss: -0.7539
# Training [100%]	Loss: -0.7554
# Training [100%]	Loss: -0.7567
# Training [100%]	Loss: -0.7583
# Training [100%]	Loss: -0.7588
# Training [100%]	Loss: -0.7580
# Training [100%]	Loss: -0.7588
# Training [100%]	Loss: -0.7599
# Training [100%]	Loss: -0.7608
# Training [100%]	Loss: -0.7615
# Training [100%]	Loss: -0.7621
# Training [100%]	Loss: -0.7635
# Training [100%]	Loss: -0.7646
# Training [100%]	Loss: -0.7658
# Training [100%]	Loss: -0.7673
# Training [100%]	Loss: -0.7687
# Training [100%]	Loss: -0.7681
# Training [100%]	Loss: -0.7694
# Training [100%]	Loss: -0.7702
# Training [100%]	Loss: -0.7716
# Training [100%]	Loss: -0.7729
# Training [100%]	Loss: -0.7743
# Training [100%]	Loss: -0.7756
# Training [100%]	Loss: -0.7736
# Training [100%]	Loss: -0.7747
# Training [100%]	Loss: -0.7760
# Training [100%]	Loss: -0.7766
# Training [100%]	Loss: -0.7771
# Training [100%]	Loss: -0.7781
# Training [100%]	Loss: -0.7789
# Training [100%]	Loss: -0.7798
# Training [100%]	Loss: -0.7807
# Training [100%]	Loss: -0.7812
# Training [100%]	Loss: -0.7822
# Training [100%]	Loss: -0.7833
# Training [100%]	Loss: -0.7840
# Training [100%]	Loss: -0.7841
# Training [100%]	Loss: -0.7853
# Training [100%]	Loss: -0.7857
# Training [100%]	Loss: -0.7865
# Training [100%]	Loss: -0.7867
# Training [100%]	Loss: -0.7858
# Training [100%]	Loss: -0.7863
# Training [100%]	Loss: -0.7862
# Training [100%]	Loss: -0.7871
# Training [100%]	Loss: -0.7879
# Training [100%]	Loss: -0.7890
# Training [100%]	Loss: -0.7898
# Training [100%]	Loss: -0.7897
# Training [100%]	Loss: -0.7896
# Training [100%]	Loss: -0.7900
# Text(0, 0.5, 'Neg Log Likelihood Loss')

# %%
#Step8: Testing the Network

model.eval()
with torch.no_grad():
    correct = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        output = model(data)
        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()
        loss = loss_func(output, target)
        total_loss.append(loss.item())
print('Performance on test data:\n\tLoss: {:.4f}\n\tAccuracy: {:.1f}%'.format(
sum(total_loss) / len(total_loss),
correct / len(test_loader) * 100)
)
# Out:
# Performance on test data:
# 	Loss: -0.8479
# 	Accuracy: 100.0%

# %%
#Testing Output:

n_samples_show = 6
count = 0
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 3))

model.eval()
with torch.no_grad():
    for batch_idx, (data, target) in enumerate(test_loader):
        if count == n_samples_show:
           break
        output = model(data)
        pred = output.argmax(dim=1, keepdim=True)
        axes[count].imshow(data[0].numpy().squeeze(), cmap='gray')
        axes[count].set_xticks([])
        axes[count].set_yticks([])
        axes[count].set_title('Predicted {}'.format(pred.item()))
        count += 1
